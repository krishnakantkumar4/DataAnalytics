# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnakantkumar4/DataAnalytics/blob/main/Data_Types_(int%2Cfloat%2Cstring).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Types In Python
# - **int** (for integers )
# - **float** (for floating point numbers)
# - **str** (for strings )
# - **list**
# - **tuple**
# - **dict** (for dictionary)
# - **set**
# - **bool**

# %% [markdown]
# ## Dynamically Typed
# Python uses *dynamic typing*, meaning you can reassign variables to different data types. This makes Python very flexible in assigning data types; it differs from other languages that are *statically typed*.

# %%
a = 5     # a is variable, 5 is an integer literal
type(a)
# Out:
# int

# %%
a = 5.5
type(a)
# Out:
# float

# %%
a = 'hello'
type(a)
# Out:
# str

# %% [markdown]
# ### Pros and Cons of Dynamic Typing
# #### Pros of Dynamic Typing
# * very easy to work with
# * faster development time
#
# #### Cons of Dynamic Typing
# * may result in unexpected bugs!

# %% [markdown]
# # Numbers (int and float)

# %%
a = 5
type(a)
# Out:
# int

# %%
b = 5.5
type(b)
# Out:
# float

# %%
b = 5.0
type(b)
# Out:
# float

# %%
x = 5                              # assigning an integer literal to a variable
y = x                              # assigning an integer variable to a variable
a = 5 + 10                         # assigning result of an expression to a variable
a = x + y
a,b,c = 5,10,15                    # multiple assignment
print(a,b,c)
a = b = c = 5
print(a,b,c)
# Out:
# 5 10 15
# 5 5 5

# %% [markdown]
# - **Operator** :  Specifies the type of operation
# - **Operands** :  Operation is performed on operands
# - **Expressions** : A collection or chain of operands and operators

# %%
a = 10
b = 20
a + b    # a and b are operands, + is an operator
# Out:
# 30

# %%
5 + 10  # 5 and 10 are operands, + is an operator
# Out:
# 15

# %%
a + b - 10 + 5 * 6 / 2    # Expression
# Out:
# 35.0

# %% [markdown]
# ## Arithmatic Operations

# %%
x = 10
y = 5

print('x + y  = ',x + y)   # addition
print('x - y  = ',x - y)   # subtraction
print('x * y  = ',x * y)   # multiplication
print('x / y  = ',x / y)   # division (normal division)
print('x // y = ',x // y)  # floor division
print('x % y  = ',x % y)   # modulous operation
print('x ** y = ',x ** y)  # power operation
# Out:
# x + y  =  15
# x - y  =  5
# x * y  =  50
# x / y  =  2.0
# x // y =  2
# x % y  =  0
# x ** y =  100000

# %%
# normal division
x = 25
y = 4
z = x / y
print(z)
type(z)
# Out:
# 6.25
# float

# %%
# normal division
x = 25
y = 5
z = x / y
print(z)
type(z)                 # normal division always returns a float type
# Out:
# 5.0
# float

# %%
# floor division
x = 25
y = 4
z = x // y
print(z)
type(z)
# Out:
# 6
# int

# %%
# floor division
x = 25
y = 4.0
z = x // y
print(z)
type(z)
# Out:
# 6.0
# float

# %%
# floor division
x = 25
y = 5.0
z = x // y
print(z)
type(z)
# Out:
# 5.0
# float

# %%
# floor division
x = 25.0
y = 4
z = x // y
print(z)
type(z)                  # if one of the operands is float, the result will also be float
# Out:
# 6.0
# float

# %%
# modulous operator
x = 25
y = 7
x % y                  # gives remainder
# Out:
# 4

# %%
# power operator
x = 2
y = 4
x ** y         # 2 raise to power 4
# Out:
# 16

# %%
2 ** 4
# Out:
# 16

# %%
16 ** 0.5
# Out:
# 4.0

# %%
16 ** (1/2)
# Out:
# 4.0

# %%
27 ** (1/3)
# Out:
# 3.0

# %% [markdown]
# #### Order of precedence of arithmatic operators

# %%
10 + 20 - (10 + 5 * 4) / 2
# Out:
# 15.0

# %%
10 + 20 - 10 + 5 ** 4 / 2             # power operator has highest priority
# Out:
# 332.5

# %%
10 + 5 % 4 / 2                       # modulos operator has higher precedence
# Out:
# 10.5

# %%
10 + 35 % 4 ** 2
# Out:
# 13

# %% [markdown]
# #### power > modulos > division > multiplication > substraction > addition

# %% [markdown]
# ## Shorthand Notation

# %%
salary = 100000
salary = salary + 10000
salary
# Out:
# 110000

# %%
salary = 100000
salary = salary - 10000
salary
# Out:
# 90000

# %%
salary = 100000
salary += 10000             # salary = salary + 10000
salary
# Out:
# 110000

# %%
x = 15
y = 4
print('x =',x)
x+=y
print('x += y =',x)
x-=y
print('x -= y =',x)
x*=y
print('x *= y =',x)
x/=y
print('x /= y =',x)
x//=y
print('x //= y =',x)
x**=y
print('x **= y =',x)
x %= 10
print('x %= y = ',x)
# Out:
# x = 15
# x += y = 19
# x -= y = 15
# x *= y = 60
# x /= y = 15.0
# x //= y = 3.0
# x **= y = 81.0
# x %= y =  1.0

# %% [markdown]
# ## Comparison Operations

# %%
x = 20
y = 10
print('x > y  is',x > y)
print('x < y  is',x < y)
print('x == y is',x == y)    # single = is assignment operation, double == is equality(comparison) operation
print('x != y is',x != y)
print('x >= y is',x >= y)
print('x <= y is',x <= y)
# Out:
# x > y  is False
# x < y  is True
# x == y is False
# x != y is True
# x >= y is False
# x <= y is True

# %%
a = 10
b = 12
a == b               # Comparison operation
# Out:
# False

# %%
a = b               # Assignment operation
a
# Out:
# 12

# %%
a = 5
b = 5
a == b
# Out:
# True

# %%
a = 6
b = 5
a == b
# Out:
# False

# %%
a = 5
b = 5
a != b
# Out:
# False

# %%
a = 6
b = 5
a != b
# Out:
# True

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a = 10
b = 10
a >= b
# Out:
# True

# %%
a = 5
b = 5
a <= b
# Out:
# True

# %% [markdown]
# ## Identity Operator

# %%
a = 5
b = 5
a is b
# Out:
# True

# %%
a = 5
b = 6
a is b
# Out:
# False

# %%
s1 = 'Hello'
s2 = 'Hello'
s1 is s2
# Out:
# True

# %%
a = 5
b = 5.0
a == b
# Out:
# True

# %%
a = 5
b = 5.0
a is b
# Out:
# False

# %% [markdown]
# ## Membership operator

# %%
s = 'membership'
'm' in s
# Out:
# True

# %%
'M' in s
# Out:
# False

# %%
'z' in s
# Out:
# False

# %%
'member' in s
# Out:
# True

# %%
message = 'Ashish killed Vikash'
'killed' in message
# Out:
# True

# %%
message = 'I am planning a bomb blast in delhi'
'blast in delhi' in message
# Out:
# True

# %%
nums = [1,2,3,4,5]
1 in nums
# Out:
# True

# %%
6 in nums
# Out:
# False

# %% [markdown]
# ### Variable naming conventions
# - Alphabets, numbers and _ can be used
# - Variable name can not start with a number

# %%
num$ = 5
# Out:
#   File "<ipython-input-52-62b9b997819f>", line 1
#     num$ = 5
#        ^
# SyntaxError: invalid syntax

# %%
2num = 5
# Out:
#   File "<ipython-input-54-c9e1a3881f0d>", line 1
#     2num = 5
#     ^
# SyntaxError: invalid decimal literal

# %%
principal amount = 100000
# Out:
#   File "<ipython-input-55-094b5f0c9fa0>", line 1
#     principal amount = 100000
#               ^
# SyntaxError: invalid syntax

# %%
principal_amount = 100000

# %%
# Valid variable names
a = 5
abc = 7
salary = 200000
x1 = 5
x2 = 6
first_name = 'Utkarsh'
last_name = 'Sharma'
_name = 'Utkarsh Sharma'

A = 4
a = 6

# %%
principal_amount = 100000
rate_of_interest = 10
duration_in_years = 5

simple_interest = principal_amount * rate_of_interest * duration_in_years / 100
print('Interest is : ', simple_interest)
# Out:
# Interest is :  50000.0

# %% [markdown]
# # ================================================

# %% [markdown]
# # Strings
# - A string is a sequence of characters

# %%
s = 'Hello'
type(s)
# Out:
# str

# %%
s = "Hello"
type(s)
# Out:
# str

# %%
s = 'My name is "Spongebob"'
print(s)
# Out:
# My name is "Spongebob"

# %%
s = "My name is 'Spongebob'"
print(s)
# Out:
# My name is 'Spongebob'

# %%
s = 'H'
type(s)
# Out:
# str

# %% [markdown]
# ## Concatenation

# %%
a = 'Hello'
b = 'Good Morning'
a + b
# Out:
# 'HelloGood Morning'

# %%
a + ' ' + b + ' ' + 'How are you?'
# Out:
# 'Hello Good Morning How are you?'

# %%
print(a + '      ' + b)
# Out:
# Hello      Good Morning

# %% [markdown]
# ## Repetition

# %%
a = 'Haha'
a * 3
# Out:
# 'HahaHahaHaha'

# %%
a * 5
# Out:
# 'HahaHahaHahaHahaHaha'

# %%
3 * a
# Out:
# 'HahaHahaHaha'

# %% [markdown]
# ## Comparisons
#
# <img align = 'left' src = 'unicode.png' style = 'width:700px; hieght:600px' />

# %%
a = 'Hello'
b = 'Hi'
a == b
# Out:
# False

# %%
a = 'Hello'
b = 'Hello'
a == b
# Out:
# True

# %%
'Hello' > 'Apple'
# Out:
# True

# %% [markdown]
# ## String Indexing

# %%
h = 'Hakuna Matata'
h
# Out:
# 'Hakuna Matata'

# %%
h[0]
# Out:
# 'H'

# %%
h[1]
# Out:
# 'a'

# %%
h[2]
# Out:
# 'k'

# %%
h[6]
# Out:
# ' '

# %%
h[7]
# Out:
# 'M'

# %%
h[11]
# Out:
# 't'

# %%
h[12]
# Out:
# 'a'

# %%
h[13]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-1eb8a96b443f> in <module>
# ----> 1 h[13]
#
# IndexError: string index out of range

# %%
# Length of a string (number of characters in the string)
len(h)
# Out:
# 13

# %%
# Reverse Indexing
h[-1]
# Out:
# 'a'

# %%
h[-2]
# Out:
# 't'

# %%
h[-3]
# Out:
# 'a'

# %%
h[-13]
# Out:
# 'H'

# %%
h[-14]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-02a31bfe2736> in <module>
# ----> 1 h[-14]
#
# IndexError: string index out of range

# %% [markdown]
# ## String Slicing
# - Slicing is used to extract substrings from a string
# - Substring is a part of string
# - Consider Markdown as a string : Mark , down, rkd, own all are substrings of Markdown
#
# The Syntax for slicing is `var[start :stop : step]`
# - start: the beginning index of the group of elements we want to access
# - stop: the ending index of the group of elements we want to access
# - step: how many steps to take, when accessing a group of elements

# %% [markdown]
# # GOOD MORNING

# %%
s = 'Good Morning'
s
# Out:
# 'Good Morning'

# %%
s[0:3]
# Out:
# 'Goo'

# %%
s[0:4]
# Out:
# 'Good'

# %%
s[0:4:1]
# Out:
# 'Good'

# %%
s[0:4:2]
# Out:
# 'Go'

# %%
s[5:12]
# Out:
# 'Morning'

# %%
s[0:12]
# Out:
# 'Good Morning'

# %%
s[3:9]
# Out:
# 'd Morn'

# %%
s[0:12:1]
# Out:
# 'Good Morning'

# %%
s[0:12:2]
# Out:
# 'Go onn'

# %%
s[0:12:3]
# Out:
# 'Gdoi'

# %%
s[1:12:3]
# Out:
# 'o rn'

# %%
s[0:8:3]
# Out:
# 'Gdo'

# %%
s[:4]         # s[0:4:1]
# Out:
# 'Good'

# %%
s[0:]        # s[0:12:1]
# Out:
# 'Good Morning'

# %%
s[:]        # s[0:12:1]
# Out:
# 'Good Morning'

# %%
s[::]      # s[0:12:1]
# Out:
# 'Good Morning'

# %%
s[-7:]
# Out:
# 'Morning'

# %%
s[-12:-8]
# Out:
# 'Good'

# %%
s[-1:-8:-1]
# Out:
# 'gninroM'

# %%
# Reversing a string
s[-1::-1]
# Out:
# 'gninroM dooG'

# %%
# Reversing a string
s[::-1]
# Out:
# 'gninroM dooG'

# %%
# Practice
s = 'Crime Master Gogo'
print(s[6:12])
print(s[13:17])
print(s[-17:-12])
print(s[-1:-5:-1])
print(s[11::-1])
s[-4:]
# Out:
# Master
# Gogo
# Crime
# ogoG
# retsaM emirC
# 'Gogo'

# %% [markdown]
# ## String Functions

# %%
s = 'Good Morning'
s
# Out:
# 'Good Morning'

# %%
len(s)
# Out:
# 12

# %%
type(s)
# Out:
# str

# %%
s.upper()
# Out:
# 'GOOD MORNING'

# %%
s                                   # original string is not changed
# Out:
# 'Good Morning'

# %%
'Hello'.upper()
# Out:
# 'HELLO'

# %%
s.lower()
# Out:
# 'good morning'

# %%
s = 'good evening welcome to the session'
s.capitalize()
# Out:
# 'Good evening welcome to the session'

# %%
s.title()
# Out:
# 'Good Evening Welcome To The Session'

# %%
s[0:12].title()
# Out:
# 'Good Evening'

# %%
s.count('o')
# Out:
# 5

# %%
s.count('welcome')
# Out:
# 1

# %%
s.count('z')
# Out:
# 0

# %%
s.find('m')
# Out:
# 18

# %%
s.find('welcome')
# Out:
# 13

# %%
s.find('o')
# Out:
# 1

# %%
s.find('z')        # When a string is not present -1 is returned
# Out:
# -1

# %%
s.index('m')
# Out:
# 18

# %%
s.index('welcome')
# Out:
# 13

# %%
s.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-3d8ee9b57202> in <module>
# ----> 1 s.index('z')
#
# ValueError: substring not found

# %%
s = '12345'
s.isdigit()
# Out:
# True

# %%
s = '123a'
s.isdigit()
# Out:
# False

# %%
s = '1.5'
s.isdigit()
# Out:
# False

# %%
s = '123'
s.isnumeric()
# Out:
# True

# %%
s = '1.5'
s.isnumeric()
# Out:
# False

# %%
s = '123abc'
s.isalnum()
# Out:
# True

# %%
s = '123abc ?'
s.isalnum()
# Out:
# False

# %%
s = 'I am Ironman'
s
# Out:
# 'I am Ironman'

# %%
s.replace('Ironman', 'Batman')
# Out:
# 'I am Batman'

# %%
s
# Out:
# 'I am Ironman'

# %%
'I am in Jaipur'.replace('Jaipur','Bengaluru')
# Out:
# 'I am in Bengaluru'

# %%
'I am in Jaipur'.replace('Dehli','Bengaluru') # nothing is replaced
# Out:
# 'I am in Jaipur'

# %%
'I live in Jaipur, Jaipur is known for Tourism, Jaipur Jaipur'.replace('Jaipur','Bengaluru')
# Out:
# 'I live in Bengaluru, Bengaluru is known for Tourism, Bengaluru Bengaluru'

# %%
'I am in Jaipur'.replace(' ','_')
# Out:
# 'I_am_in_Jaipur'

# %%
s = 'Good morning how are you'
s.split()
# Out:
# ['Good', 'morning', 'how', 'are', 'you']

# %%
s = 'Good morning how are you'
s.split('g')
# Out:
# ['Good mornin', ' how are you']

# %%
s = 'Good morning how are you'
s.split('how')
# Out:
# ['Good morning ', ' are you']

# %%
s.split('o')
# Out:
# ['G', '', 'd m', 'rning h', 'w are y', 'u']

# %%
s = 'Spongebob Squarepants 15 Seaworld'
details = s.split()
details
# Out:
# ['Spongebob', 'Squarepants', '15', 'Seaworld']

# %%
first_name = details[0]
last_name = details[1]
age = int(details[2])
city = details[3]

print('\nThe Details Are : ')
print('First Name : ',first_name)
print('Last Name  : ',last_name)
print('Age        : ',age)
print('City       : ',city)
# Out:
# The Details Are :
# First Name :  Spongebob
# Last Name  :  Squarepants
# Age        :  15
# City       :  Seaworld

# %%
word_list = ['Good', 'morning', 'how', 'are', 'you']
' '.join(word_list)
# Out:
# 'Good morning how are you'

# %%
l = ['Good', 'morning', 'how', 'are', 'you']
'@@@'.join(l)
# Out:
# 'Good@@@morning@@@how@@@are@@@you'

# %% [markdown]
# # Important Concepts
# - Mutable
# - Immutable
# - Iterable
# - Non Iterable
# - Sequence
# - Key Value Pair data types

# %% [markdown]
# # Practice

# %%
details = input('Enter the details(firstname lastname age city) : ').split()

first_name = details[0]
last_name  = details[1]
age = int(details[2])
city = details[3]

print('\nThe details are : ')
print('First Name : ', first_name)
print('Last Name  : ', last_name)
print('Age        : ', age)
print('City       : ', city)
# Out:
# Enter the details(firstname lastname age city) : Spongebob Squarepants 15 Seaworld
#
# The details are :
# First Name :  Spongebob
# Last Name  :  Squarepants
# Age        :  15
# City       :  Seaworld

# %%
# Swapping two numbers (Method 1)
num1 = int(input('Enter First Number  : '))
num2 = int(input('Enter Second Number : '))
print('Before Swapping : ')
print('Num1 = ',num1)
print('Num2 = ',num2)
temp = num1
num1 = num2
num2 = temp
print('After Swapping : ')
print('Num1 = ',num1)
print('Num2 = ',num2)
# Out:
# Enter First Number  : 10
# Enter Second Number : 5
# Before Swapping :
# Num1 =  10
# Num2 =  5
# After Swapping :
# Num1 =  5
# Num2 =  10

# %%
# Swapping two numbers (Method 2)
num1 = int(input('Enter First Number  : '))
num2 = int(input('Enter Second Number : '))
print('Before Swapping : ')
print('Num1 = ',num1)
print('Num2 = ',num2)
num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2
print('After Swapping : ')
print('Num1 = ',num1)
print('Num2 = ',num2)
# Out:
# Enter First Number  : 10
# Enter Second Number : 5
# Before Swapping :
# Num1 =  10
# Num2 =  5
# After Swapping :
# Num1 =  5
# Num2 =  10

# %%
# Swapping two numbers (Method 3)
num1 = int(input('Enter First Number  : '))
num2 = int(input('Enter Second Number : '))
print('Before Swapping : ')
print('Num1 = ',num1)
print('Num2 = ',num2)

num1, num2 = num2, num1

print('After Swapping : ')
print('Num1 = ',num1)
print('Num2 = ',num2)
# Out:
# Enter First Number  : 10
# Enter Second Number : 5
# Before Swapping :
# Num1 =  10
# Num2 =  5
# After Swapping :
# Num1 =  5
# Num2 =  10

# %%
# Take a string as input and print number of words
words = input('Enter the string : ').split()
print('The number of words in the given string are : ', len(words))
# Out:
# Enter the string : billo bagge billeya da ki karegi
# The number of words in the given string are :  6

# %%
details = input('Enter the details(amount duration rate) : ').split()
amount = int(details[0])
duration = float(details[1])
rate = float(details[2])

interest = amount * duration * rate / 100
print('The interest amount is : ', interest)
# Out:
# Enter the details(amount duration rate) : 1000000 4.5 9.5
# The interest amount is :  427500.0
