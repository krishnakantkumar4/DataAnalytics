# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnakantkumar4/DataAnalytics/blob/main/Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Hello Python for Data Analytics
print('Hello Python for Data Analytics')
print('Welcome in the Python World')
# Out:
# Hello Python for Data Analytics
# Welcome in the Python World

# %%
name = 'krishnakant'
print(name)
# Out:
# krishnakant

# %%
name = input()
print(name)
# Out:
# krishnakant
# krishnakant

# %%
#Write a program to take first name last name and gender as input and print them
fname = input('Enter your first name:')
lname = input('Enter your last name:')
gender = input('Enter your gender:')
print('The Personal details of :' ,fname)
print('Your first name is:',fname)
print('Your last name is:',lname)
print('Your gender is:',gender)
# Out:
# Enter your first name:krishnakant
# Enter your last name:kumar
# Enter your gender:male
# The Personal details of : krishnakant
# Your first name is: krishnakant
# Your last name is: kumar
# Your gender is: male

# %%
from types import CoroutineType
# write a program to take first name last name gender city state country
fname = input("Enter your first name: ")
lname = input("Enter your last name: ")
gender = input("Enter your gender: ")
City = input("Enter your city: ")
State = input("Enter your state: ")
Country = input("Enter your country: ")
print("The personal details of:", fname)
print("Your first name is:", fname)
print("Your last name is:", lname)
print("Your gender is:", gender)
print("Your city is:", City)
print("Your state is:", State)
print("Your country is:", Country)
# Out:
# Enter your first name: krishnakant
# Enter your last name: kumar
# Enter your gender: male
# Enter your city: lakhisarai
# Enter your state: Bihar
# Enter your country: India
# The personal details of: krishnakant
# Your first name is: krishnakant
# Your last name is: kumar
# Your gender is: male
# Your city is: lakhisarai
# Your state is: Bihar
# Your country is: India

# %%
#xreate a program to take two number and add them
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
sum = num1 + num2 # addition operation + : Operator
print("The sum of", num1, "and", num2, "is", sum)
# Out:
# Enter the first number: 1000
# Enter the second number: 2000
# The sum of 1000 and 2000 is 3000

# %%
# Input is always taken as String so python perform concetanation
print('Hello ' + 'Everyone')
# Out:
# Hello Everyone

# %%
# We need to convert String input into Integer
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
sum =  num1 + num2
print('The Sum of ', num1, 'and', num2, 'is', sum)
# Out:
# Enter the first number: 1000
# Enter the second number: 2000
# The Sum of  1000 and 2000 is 3000

# %%
#create the program the take number to products purchased and the price per product and print the total cost
no_of_purchased_product = int(input("Enter the number of products purchased: "))
price_per_product = int(input("Enter the price per product: "))
Total_Cost = no_of_purchased_product * price_per_product
print("The total cost of", num1, "products purchased at", num2, "per product is", Total_Cost)
# Out:
# Enter the number of products purchased: 1000
# Enter the price per product: 10
# The total cost of 1000 products purchased at 2000 per product is 10000

# %%
#create the program which takes priciple amount rate of interest and duration in years as input and print the sinple interest
principle_amount = int(input("Enter the principle amount: "))
rate_of_interest = int(input("Enter the rate of interest: "))
duration_in_years = int(input("Enter the duration in years: "))
simple_interest = (principle_amount * rate_of_interest * duration_in_years) / 100
print("The simple interest is: ", simple_interest)
# Out:
# Enter the principle amount: 1000
# Enter the rate of interest: 10
# Enter the duration in years: 10
# The simple interest is:  1000.0

# %%
#create the program which takes priciple amount rate of interest and duration in years as input and print the sinple interest
principle_amount = float(input("Enter the principle amount: ")) #float datatype use for decimal value
rate_of_interest = float(input("Enter the rate of interest: "))
duration_in_years = float(input("Enter the duration in years: "))
simple_interest = (principle_amount * rate_of_interest * duration_in_years) / 100
print("The simple interest is: ", simple_interest)
# Out:
# Enter the principle amount: 1000
# Enter the rate of interest: 20
# Enter the duration in years: 10
# The simple interest is:  2000.0

# %%
#create a program which takes two two number as input and swap their value
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
print("Before swapping: a =", a, "b =", b)
temp = a
a = b
b = temp
print("After swapping: a =", a, "b =", b)
# Out:
# Enter the first number: 200
# Enter the second number: 100
# Before swapping: a = 200 b = 100
# After swapping: a = 100 b = 200

# %% [markdown]
# Numbers (Int and Float)

# %%
a = 5
type (a)
# Out:
# int

# %%
b = 5.5
type (b)
# Out:
# float

# %%
x = 5 # assigning an integer to a variable
y = x # assigning an integer variable to a variable
a = 5 + 10 # assigning result of an expresion to a variable
a = x + y
a,b,c = 5,10,15 # multiple assignment
print (a,b,c)
a = b = c = 5
print (a,b,c)
# Out:
# 5 10 15
# 5 5 5

# %% [markdown]
# Operator : Specifies the type of operation
#
# Operants : Operation is performed on operants
#
# Expressions : A Collection or chain of operants and operators

# %%
a = 10
b = 20 # a and b are operads, + is an operator
a + b
# Out:
# 30

# %%
5 + 10 # 5 and 10 are operads, + is an operator
# Out:
# 15

# %%
a + b - 10 + 5 * 6/2 #Expression
# Out:
# 35.0

# %% [markdown]
# Arithmatic Operations

# %%
x = 10
y = 10
print ('x + y =', x + y) # Addition
print ('x - y =', x - y) # Subtraction
print ('x * y =', x * y) # Multiplication
print ('x / y =', x / y) # Division
print ('x // y =', x // y) # Floor Division
print ('x ** y =', x ** y) # Exponent (Power Operations)
print ('x % y =', x % y) # Modulus Operations
# Out:
# x + y = 20
# x - y = 0
# x * y = 100
# x / y = 1.0
# x // y = 1
# x ** y = 10000000000
# x % y = 0

# %%
# Normal Division
x = 25
y = 4
z = x / y
print(z)
type (z) # normal divion always returs a float type
# Out:
# 6.25
# float

# %%
# Normal Division
x = 25
y = 5
z = x / y
print(z)
type (z) # normal divion always returs a float type
# Out:
# 5.0
# float

# %%
# Floor Division
x = 25
y = 4
z = x // y
print(z)
type (z)
# Out:
# 6
# int

# %%
# Floor Division
x = 25
y = 5
z = x // y
print(z)
type (z)
# Out:
# 5
# int

# %%
# Floor Division
x = 25
y = 4.0
z = x // y
print(z)
type (z) # If any variable will be float then they will give result type float
# Out:
# 6.0
# float

# %%
# Modulus Operator
x = 25
y = 7
z = x % y
print(z)
type (z)
# Out:
# 4
# int

# %%
# Modulus Operator
x = 25
y = 7.0
z = x % y
print(z)
type (z)
# Out:
# 4.0
# float

# %%
# Power Operator
x = 2
y = 4
z = x ** y # 2 raise to the power 4
print(z)
type (z)
# Out:
# 16
# int

# %%
16 ** 0.5
# Out:
# 4.0

# %%
16 ** (1/2)
# Out:
# 4.0

# %%
27 ** (1/3)
# Out:
# 3.0

# %% [markdown]
# Order of Precedence  of arithmatic operators

# %%
10 + 20 - 10 + 5 * 4 / 2
# Out:
# 30.0

# %%
10 + 20 - 10 + 5 ** 4 / 2 # Power Operator has higher priority
# Out:
# 332.5

# %%
10 + 20 - 10 + 5 % 4 / 2 # Modulus Operator has higher priority
# Out:
# 20.5

# %% [markdown]
# Power > Modulus > Division > Multiplication > Subtraction > Addition

# %% [markdown]
# Shorthand Notation

# %%
salary = 100000
salary = salary + 10000
salary
# Out:
# 110000

# %%
salary = 10000
salary += 1000
salary
# Out:
# 11000

# %%
salaruy = 100000
salary -= 1000
salary
# Out:
# 10000

# %% [markdown]
# Comparision Operations

# %%
x = 10
y = 15
print ('x > y is', x > y) # Greater than
print ('x < y is', x < y) # Less than
print ('x == y is', x == y) # Equal to
print ('x != y is', x != y) # Not equal to
print ('x >= y is', x >= y) # Greater than or equal to
print ('x <= y is', x <= y)
print ('x is y is', x is y) # Identity Operator
print ('x is not y is', x is not y) # Identity Operator
print ('x is y is', x is y) # Identity Operator
print ('x is not y is', x is not y)
# Out:
# x > y is False
# x < y is True
# x == y is False
# x != y is True
# x >= y is False
# x <= y is True
# x is y is False
# x is not y is True
# x is y is False
# x is not y is True

# %% [markdown]
# Identity Operator

# %%
x = 10
y = 15
print ('x is not y is', x is not y) # Identity Operator
print ('x is y is', x is y) # Identity Operator
print ('x is not y is', x is not y)
# Out:
# x is not y is True
# x is y is False
# x is not y is True

# %% [markdown]
# Membership Operators

# %%
s = 'membership'
'm' in s
# Out:
# True

# %%
'n' in s
# Out:
# False

# %%
'e' in s
# Out:
# True

# %%
'M' in s
# Out:
# False

# %%
nums = [1,2,3,4,5]
1 in nums
# Out:
# True

# %% [markdown]
# # Variable naming Conventions
# 1. Alphabets, numbers and _ can be used
# 2. Variable name can not start with number

# %%
#Valid Variable Name
a =5
abc = 7
salary = 10000
x1 = 5
x2 = 6
first_name = 'krishnakant'
last_name = 'Singh'
_name = 'krishnakant'

# %% [markdown]
# Strings
# * A string is a sequence of characters

# %%
s = 'Hello'
type(s)
# Out:
# str

# %%
s = 'My name is krishnakant'
print (s)
# Out:
# My name is krishnakant

# %%
s = 'My name is "Krishnakant"'
print (s)
# Out:
# My name is "Krishnakant"

# %%
s = 'H'
type (s)
# Out:
# str

# %% [markdown]
# Concatenation

# %%
a = 'Hello'
b = 'Good Morning'
a + " " + b # white space is also a character
# Out:
# 'Hello Good Morning'

# %%
a + " " + b + " " + "How are you?"
# Out:
# 'Hello Good Morning How are you?'

# %% [markdown]
# Repetition

# %%
a = 'Haha'
a*3
# Out:
# 'HahaHahaHaha'

# %%
a*5
# Out:
# 'HahaHahaHahaHahaHaha'

# %% [markdown]
# Comparisons

# %%
a = 'Hello'
b = 'Hi'
a == b
# Out:
# False

# %%
a = 'Hello'
b = 'Hello'
a == b
# Out:
# True

# %%
'Hello' > 'Apple'
# Out:
# True

# %%
print("Unicode Table (Common ASCII characters):")
print("Code Point (Hex) | Code Point (Dec) | Character")
print("---------------------------------------------------")

# Iterate through a common range of printable ASCII characters
for i in range(32, 127): # ASCII printable characters start from 32 (space) to 126 (tilde)
    char = chr(i)
    print(f"      {hex(i)[2:].upper():<10} |       {i:<10} | {char}")

print("\nFor a more extensive Unicode table, the range can be expanded.")
# Out:
# Unicode Table (Common ASCII characters):
# Code Point (Hex) | Code Point (Dec) | Character
# ---------------------------------------------------
#       20         |       32         |
#       21         |       33         | !
#       22         |       34         | "
#       23         |       35         | #
#       24         |       36         | $
#       25         |       37         | %
#       26         |       38         | &
#       27         |       39         | '
#       28         |       40         | (
#       29         |       41         | )
#       2A         |       42         | *
#       2B         |       43         | +
#       2C         |       44         | ,
#       2D         |       45         | -
#       2E         |       46         | .
#       2F         |       47         | /
#       30         |       48         | 0
#       31         |       49         | 1
#       32         |       50         | 2
#       33         |       51         | 3
#       34         |       52         | 4
#       35         |       53         | 5
#       36         |       54         | 6
#       37         |       55         | 7
#       38         |       56         | 8
#       39         |       57         | 9
#       3A         |       58         | :
#       3B         |       59         | ;
#       3C         |       60         | <
#       3D         |       61         | =
#       3E         |       62         | >
#       3F         |       63         | ?
#       40         |       64         | @
#       41         |       65         | A
#       42         |       66         | B
#       43         |       67         | C
#       44         |       68         | D
#       45         |       69         | E
#       46         |       70         | F
#       47         |       71         | G
#       48         |       72         | H
#       49         |       73         | I
#       4A         |       74         | J
#       4B         |       75         | K
#       4C         |       76         | L
#       4D         |       77         | M
#       4E         |       78         | N
#       4F         |       79         | O
#       50         |       80         | P
#       51         |       81         | Q
#       52         |       82         | R
#       53         |       83         | S
#       54         |       84         | T
#       55         |       85         | U
#       56         |       86         | V
#       57         |       87         | W
#       58         |       88         | X
#       59         |       89         | Y
#       5A         |       90         | Z
#       5B         |       91         | [
#       5C         |       92         | \
#       5D         |       93         | ]
#       5E         |       94         | ^
#       5F         |       95         | _
#       60         |       96         | `
#       61         |       97         | a
#       62         |       98         | b
#       63         |       99         | c
#       64         |       100        | d
#       65         |       101        | e
#       66         |       102        | f
#       67         |       103        | g
#       68         |       104        | h
#       69         |       105        | i
#       6A         |       106        | j
#       6B         |       107        | k
#       6C         |       108        | l
#       6D         |       109        | m
#       6E         |       110        | n
#       6F         |       111        | o
#       70         |       112        | p
#       71         |       113        | q
#       72         |       114        | r
#       73         |       115        | s
#       74         |       116        | t
#       75         |       117        | u
#       76         |       118        | v
#       77         |       119        | w
#       78         |       120        | x
#       79         |       121        | y
#       7A         |       122        | z
#       7B         |       123        | {
#       7C         |       124        | |
#       7D         |       125        | }
#       7E         |       126        | ~
#
# For a more extensive Unicode table, the range can be expanded.

# %% [markdown]
# String Indexing

# %%
h = 'Hakuna Matata'
h
# Out:
# 'Hakuna Matata'

# %%
h [0]
# Out:
# 'H'

# %%
h [1]
# Out:
# 'a'

# %%
h [7]
# Out:
# 'M'

# %%
# Length of a string (number of characters in a string)
len (h)
# Out:
# 13

# %% [markdown]
# Reverse Indexing

# %%
print (h)
# Out:
# Hakuna Matata

# %%
h [-1]
# Out:
# 'a'

# %%
h [-2]
# Out:
# 't'

# %% [markdown]
# String Slicing
#
# 1. Slicing is used to extract substrings from a string
#
# 2. substring is a part of string
#
# 2. Consider Markdown as a string Mark, down, rkd, own all are substring of 'Markdown'
#
#
# The syntax for slicing is var [start : stop : step]
#
# 1. start the begining index of the group of elements we want to access
#
# 2. stop the ending index of the group of elements we want to access
#
# 3. step how many steps to take whenaccessing a group of elements

# %% [markdown]
# Good Morning

# %%
s = 'Good Morning'
s
# Out:
# 'Good Morning'

# %%
s [0 : 3]
# Out:
# 'Goo'

# %%
s [0 :4]
# Out:
# 'Good'

# %%
s [0 : 4 : 2]
# Out:
# 'Go'

# %%
s [0 : 12 : 2]
# Out:
# 'Go onn'

# %%
s [:4] # [0 : 4 : 1]
# Out:
# 'Good'

# %%
s [0:] # [0 : 12 : 1]
# Out:
# 'Good Morning'

# %%
s [:] # [0 : 12 : 1]
# Out:
# 'Good Morning'

# %%
s [-12 : -8]
# Out:
# 'Good'

# %%
#Reversing a string
s [-1 :: -1]
# Out:
# 'gninroM dooG'

# %%
s = 'Master Gogo'
print (s[6:12])
# Out:
#  Gogo

# %%
#Reversing a string
s [::-1]
# Out:
# 'ogoG retsaM'

# %% [markdown]
# String Function
#
# 1. Inbuilt (predefined)
# 2. User defined (created by user)

# %%
s = 'Good Morning'
s.upper()
# Out:
# 'GOOD MORNING'

# %%
# original string is not changed
s
# Out:
# 'Good Morning'

# %%
'hello'.upper()
# Out:
# 'HELLO'

# %%
s.lower()
# Out:
# 'good morning'

# %%
s = 'good morning welcome to the session'
s.capitalize()
# Out:
# 'Good morning welcome to the session'

# %%
s.title()
# Out:
# 'Good Morning Welcome To The Session'

# %%
s.count('o')
# Out:
# 6

# %%
s.count ('welcome')
# Out:
# 1

# %%
s.count('z')
# Out:
# 0

# %%
s.find('o')
# Out:
# 1

# %%
s.find('welcome')
# Out:
# 13

# %%
print(s.find('z')) #when a string is not present -1 is returned
# Out:
# -1

# %%
s.index('m')
# Out:
# 5

# %%
s = '12345'
s.isdigit()
# Out:
# True

# %%
s = '123a'
s.isdigit()
# Out:
# False

# %%
s = '1.5'
s.isdigit()
# Out:
# False

# %%
s = '1234'
s.isnumeric()
# Out:
# True

# %%
s = '1.5'
s.isnumeric()
# Out:
# False

# %%
s = '123abc'
s.isalnum()
# Out:
# True

# %%
s = 'i am ironman'
s
# Out:
# 'i am ironman'

# %%
s.replace('ironman', 'thor')
# Out:
# 'i am thor'

# %%
'I am ironman'.replace('ironman', 'thor')
# Out:
# 'I am thor'

# %%
'I am ironman'.replace('Batman', 'thor') #nothing replaced
# Out:
# 'I am ironman'

# %%
'I am ironman'.replace(' ', '_')
# Out:
# 'I_am_ironman'

# %%
s = 'Good morning how are you'
s.split()
# Out:
# ['Good', 'morning', 'how', 'are', 'you']

# %%
s.split('g')
# Out:
# ['Good mornin', ' how are you']

# %%
s.split('how')
# Out:
# ['Good morning ', ' are you']

# %%
s.split('o')
# Out:
# ['G', '', 'd m', 'rning h', 'w are y', 'u']

# %%
s = 'spongebob squarepants 15 seaworld'
details = s.split()
details
# Out:
# ['spongebob', 'squarepants', '15', 'seaworld']

# %%
first_name = details[0]
last_name = details[1]
age = details[2]
city = details[3]
first_name, last_name, age, city
print ('The details are :')
print ('first_name :',first_name)
print ('last_name :',last_name)
print ('age :',age)
print ('city :',city)
# Out:
# The details are :
# first_name : spongebob
# last_name : squarepants
# age : 15
# city : seaworld

# %%
print(details)
# Out:
# ['spongebob', 'squarepants', '15', 'seaworld']

# %%
I = ['Good' , 'morning' , 'How' , 'are' , 'you']
'@@@'.join(I)
# Out:
# 'Good@@@morning@@@How@@@are@@@you'

# %% [markdown]
# **Important Concept**

# %% [markdown]
# 1. Mutable
#
# 2. immutable
#
# 3. Iterable
#
# 4. Non Iterable
#
# 5. Sequence
#
# 6. key values pair data types

# %% [markdown]
# **Practice**

# %%
details = input('Enter your details (first_name last_name age city):').split()

first_name = details[0]
last_name = details[1]
age = details[2]
city = details[3]

print ('The details are :')
print ('first_name :',first_name)
print ('last_name :',last_name)
print ('age :',age)
print ('city :',city)
# Out:
# Enter your details (first_name last_name age city):Krishnakant Kumar 30 bhagalpur
# The details are :
# first_name : Krishnakant
# last_name : Kumar
# age : 30
# city : bhagalpur

# %% [markdown]
# **List**

# %% [markdown]
# 1. lists are collections in python
# 2. Lists are defined using [ ]
# 3. Lists can store multiple elements of different data types seperated by ' , ' ---> Comma
# 4. Lists are indexed mutable iterable

# %%
l1 =[1,2,3,4,5]
print(l1)
type(l1)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
list1 = [10,20,30,40,50] #list are mutable (item assignment possible)
list1 [3] = 60
list1
# Out:
# [10, 20, 30, 60, 50]

# %%
s = 'hello' # Strings are immutable (item assignment not possible)
s[3] = 'z'
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-262/3987344025.py in <cell line: 0>()
#       1 s = 'hello'
# ----> 2 s[3] = 'z'
#       3 s
#
# TypeError: 'str' object does not support item assignment

# %%
for i in list1:  #list and string both are iterable
  print(i, end = ' ' )

print()
for i in s:
  print(i, end = ' ')
# Out:
# 10 20 30 60 50
# h e l l o

# %%
l1 = ['abc' , 'xyz' , 'pqr']
l1
# Out:
# ['abc', 'xyz', 'pqr']

# %%
krishna_marks = [90,80.85,95,97]
krishna_marks
# Out:
# [90, 80.85, 95, 97]

# %%
l1 = [1,2,3,4, 4.5, 6.5,'hello',[9,10,11], [12,13,14], True , False ] #Any datatype can be stored in list
l1
# Out:
# [1, 2, 3, 4, 4.5, 6.5, 'hello', [9, 10, 11], [12, 13, 14], True, False]
